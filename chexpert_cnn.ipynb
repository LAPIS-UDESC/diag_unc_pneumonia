# %%
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
import pandas
import numpy
import os

RANDOM_SEED = 0
DATASET_DIR = os.path.join(os.getcwd(), 'chexpert/chexpertchestxrays-u20210408')
DATA_CSV_PATH = os.path.join(DATASET_DIR, 'train_cheXbert.csv')
CHEXNET_PATH = os.path.join(os.getcwd(), 'modelos/pre_treinados/brucechou1983_CheXNet_Keras_0.3.0_weights.h5')
LABEL_DICT = {0: 0, 1: 1, -1: 2}

data_df = pandas.read_csv(DATA_CSV_PATH)

# Removendo as visões laterais
data_df = data_df[data_df['Frontal/Lateral'] == 'Frontal']

# Substituindo NaN por zero
data_df.fillna(0, inplace=True)

# Tratando caminhos das imagens
img_paths = data_df['Path'].values
img_paths = list(map(lambda path: os.path.join(os.getcwd(), DATASET_DIR, path), img_paths))

# Tratando labels
labels = data_df['Pneumonia'].values
labels = numpy.array(list(map(lambda y: LABEL_DICT[int(y)], labels)))

print(numpy.count_nonzero(labels == 0))
print(numpy.count_nonzero(labels == 1))
print(numpy.count_nonzero(labels == 2))

# Realizando undersampling
img_paths, labels = (
    RandomUnderSampler(random_state=RANDOM_SEED)
    .fit_resample(numpy.array(img_paths).reshape(-1, 1), labels)
)
img_paths = img_paths.flatten()
# Out:
# 2024-09-18 18:27:43.045872: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-18 18:27:43.062161: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-18 18:27:43.067102: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-18 18:27:43.079456: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-18 18:27:45.275274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 170685
# 3738
# 16604

# %%
import keras
from keras import backend as K
from keras import layers
from keras import callbacks
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import gc

NUM_FOLDS = 15
BATCH_SIZE = 32
IMG_SIZE = 224

def preprocess_and_load(img_path, label):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE], antialias=True)
    img = keras.applications.densenet.preprocess_input(img)
    return img, label


def train_model(model, train_set, val_set, finetune):
    if finetune:
        model.get_layer('chexnet').trainable = True
        lr = 1e-4
        epochs=4
    else:
        model.get_layer('chexnet').trainable = False
        lr = 1e-3
        epochs=40
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss=keras.losses.CategoricalCrossentropy(),
        metrics=[
            keras.metrics.AUC(curve='ROC', name='roc_auc'),
            'accuracy'
        ],
    )
    
    history = model.fit(
        train_set,
        validation_data=val_set,
        epochs=epochs,
        verbose=1,
        callbacks=[
            callbacks.EarlyStopping(
                monitor='val_loss',
                patience=8,
                min_delta=1e-4,
                restore_best_weights=True,
                verbose=1
            ),
            callbacks.ReduceLROnPlateau(
                patience=4,
                min_delta=1e-4,
                verbose=1
            )
        ],
    )
    return history

def create_model():
        # Carregando os pesos do chexnet
        densenet = tf.keras.applications.DenseNet121(
            weights=None,
            include_top=False,
            input_shape=(IMG_SIZE, IMG_SIZE, 3),
            pooling='avg',
        )
        output = layers.Dense(14, activation='sigmoid', name='output')(densenet.layers[-1].output)
        chexnet = keras.Model(inputs=densenet.input, outputs=output)
        chexnet.load_weights(CHEXNET_PATH)
        chexnet = keras.Model(name='chexnet', inputs=chexnet.input, outputs=chexnet.layers[-2].output)

        # Modelo principal
        inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
        x = layers.RandomFlip('horizontal')(inputs)
        x = chexnet(x, training=False)
        x = layers.Dropout(0.25)(x)
        x = layers.Dense(
            units=512,
            activation='relu',
        )(x)
        x = layers.Dense(
            units=256,
            activation='relu',
        )(x)
        x = layers.Dense(
            units=128,
            activation='relu',
        )(x)
        outputs = layers.Dense(
            name='output_layer',
            units=3,
            activation='softmax'
        )(x)
        model = keras.Model(inputs, outputs)
        return model

tprs = []
aucs = []
mean_fpr = numpy.linspace(0, 1, 100)

'''
    Seeds usadas:
    0, 42, 2024, 2002, 412, 253,
    54, 621, 3432, 333, 1234, 460,
    12, 3451, 553, 541
'''

for fold, seed in enumerate([12, 3451, 553, 541]):
    print(f'Fold {fold}...')
    
    x_train, x_val, y_train, y_val = train_test_split(
        img_paths,
        labels,
        test_size=0.15,
        stratify=labels,
        random_state=seed,
    )

    y_train = keras.utils.to_categorical(y_train)
    y_val = keras.utils.to_categorical(y_val)

    # Configurando dataset de treino
    train_set = (
        tf.data.Dataset.from_tensor_slices((x_train, y_train))
        .map(preprocess_and_load, num_parallel_calls=tf.data.AUTOTUNE)
        .cache()
        .shuffle(buffer_size=1000)
        .batch(BATCH_SIZE)
        .prefetch(buffer_size=tf.data.AUTOTUNE)
    )

    # Configurando dataset de validação
    val_set = (
        tf.data.Dataset.from_tensor_slices((x_val, y_val))
        .map(preprocess_and_load, num_parallel_calls=tf.data.AUTOTUNE)
        .cache()
        .batch(BATCH_SIZE)
        .prefetch(buffer_size=tf.data.AUTOTUNE)
    )

    model = create_model()
    _ = train_model(model, train_set, val_set, finetune=False)
    _ = train_model(model, train_set, val_set, finetune=True)

    # Testando modelo, recuperando métricas
    y_pred = model.predict(val_set)

    # Calculando taxa de falsos positivos e verdadeiros positivos
    fpr, tpr, _ = roc_curve(y_val[:, 2], y_pred[:, 2])
    roc_auc = auc(fpr, tpr)
    interp_tpr = numpy.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(roc_auc)

    del model, train_set, val_set
    gc.collect()
    K.clear_session()
# Out:
# Fold 0...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726618265.876418 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.354283 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.354551 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.356004 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.356210 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.356400 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.574996 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.575228 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726618268.575421 3262769 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-17 21:11:08.575571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4005 MB memory:  -> device: 0, name: Quadro P2200, pci bus id: 0000:08:00.0, compute capability: 6.1
# Epoch 1/40
# 2024-09-17 21:11:29.527173: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:3: Filling up shuffle buffer (this may take a while): 461 of 1000
# 2024-09-17 21:11:39.561492: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:3: Filling up shuffle buffer (this may take a while): 974 of 1000
# 2024-09-17 21:11:40.200688: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726618300.700323 3262878 service.cc:146] XLA service 0x7fca64002350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726618300.700358 3262878 service.cc:154]   StreamExecutor device (0): Quadro P2200, Compute Capability 6.1
# 2024-09-17 21:11:41.069746: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-17 21:11:42.885812: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#   1/298 ━━━━━━━━━━━━━━━━━━━━ 3:54:53 47s/step - accuracy: 0.2500 - loss: 1.1876 - roc_auc: 0.3765
# I0000 00:00:1726618319.571512 3262878 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 267s 740ms/step - accuracy: 0.3540 - loss: 1.1130 - roc_auc: 0.5250 - val_accuracy: 0.3803 - val_loss: 1.0836 - val_roc_auc: 0.5803 - learning_rate: 0.0010
# Epoch 2/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 126ms/step - accuracy: 0.4196 - loss: 1.0659 - roc_auc: 0.6036 - val_accuracy: 0.4652 - val_loss: 1.0433 - val_roc_auc: 0.6553 - learning_rate: 0.0010
# Epoch 3/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4205 - loss: 1.0569 - roc_auc: 0.6171 - val_accuracy: 0.4480 - val_loss: 1.0474 - val_roc_auc: 0.6325 - learning_rate: 0.0010
# Epoch 4/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4347 - loss: 1.0496 - roc_auc: 0.6254 - val_accuracy: 0.3535 - val_loss: 1.0906 - val_roc_auc: 0.5663 - learning_rate: 0.0010
# Epoch 5/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4180 - loss: 1.0634 - roc_auc: 0.6097 - val_accuracy: 0.3969 - val_loss: 1.0652 - val_roc_auc: 0.6040 - learning_rate: 0.0010
# Epoch 6/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4329 - loss: 1.0542 - roc_auc: 0.6210
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4329 - loss: 1.0542 - roc_auc: 0.6210 - val_accuracy: 0.4118 - val_loss: 1.0619 - val_roc_auc: 0.6160 - learning_rate: 0.0010
# Epoch 7/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4388 - loss: 1.0431 - roc_auc: 0.6363 - val_accuracy: 0.4676 - val_loss: 1.0284 - val_roc_auc: 0.6600 - learning_rate: 1.0000e-04
# Epoch 8/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4466 - loss: 1.0441 - roc_auc: 0.6372 - val_accuracy: 0.4516 - val_loss: 1.0385 - val_roc_auc: 0.6433 - learning_rate: 1.0000e-04
# Epoch 9/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4422 - loss: 1.0379 - roc_auc: 0.6408 - val_accuracy: 0.4700 - val_loss: 1.0281 - val_roc_auc: 0.6588 - learning_rate: 1.0000e-04
# Epoch 10/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4453 - loss: 1.0368 - roc_auc: 0.6433 - val_accuracy: 0.4676 - val_loss: 1.0275 - val_roc_auc: 0.6583 - learning_rate: 1.0000e-04
# Epoch 11/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4485 - loss: 1.0345 - roc_auc: 0.6455 - val_accuracy: 0.4670 - val_loss: 1.0299 - val_roc_auc: 0.6551 - learning_rate: 1.0000e-04
# Epoch 12/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4570 - loss: 1.0341 - roc_auc: 0.6479 - val_accuracy: 0.4670 - val_loss: 1.0296 - val_roc_auc: 0.6554 - learning_rate: 1.0000e-04
# Epoch 13/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4473 - loss: 1.0409 - roc_auc: 0.6400 - val_accuracy: 0.4664 - val_loss: 1.0241 - val_roc_auc: 0.6634 - learning_rate: 1.0000e-04
# Epoch 14/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4540 - loss: 1.0308 - roc_auc: 0.6512 - val_accuracy: 0.4676 - val_loss: 1.0303 - val_roc_auc: 0.6561 - learning_rate: 1.0000e-04
# Epoch 15/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4535 - loss: 1.0359 - roc_auc: 0.6457 - val_accuracy: 0.4635 - val_loss: 1.0328 - val_roc_auc: 0.6523 - learning_rate: 1.0000e-04
# Epoch 16/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4570 - loss: 1.0323 - roc_auc: 0.6479 - val_accuracy: 0.4682 - val_loss: 1.0231 - val_roc_auc: 0.6633 - learning_rate: 1.0000e-04
# Epoch 17/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4357 - loss: 1.0416 - roc_auc: 0.6376 - val_accuracy: 0.4700 - val_loss: 1.0218 - val_roc_auc: 0.6655 - learning_rate: 1.0000e-04
# Epoch 18/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4464 - loss: 1.0361 - roc_auc: 0.6428 - val_accuracy: 0.4682 - val_loss: 1.0274 - val_roc_auc: 0.6579 - learning_rate: 1.0000e-04
# Epoch 19/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4533 - loss: 1.0360 - roc_auc: 0.6441 - val_accuracy: 0.4676 - val_loss: 1.0224 - val_roc_auc: 0.6649 - learning_rate: 1.0000e-04
# Epoch 20/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4526 - loss: 1.0304 - roc_auc: 0.6479 - val_accuracy: 0.4682 - val_loss: 1.0278 - val_roc_auc: 0.6583 - learning_rate: 1.0000e-04
# Epoch 21/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4500 - loss: 1.0388 - roc_auc: 0.6422
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4500 - loss: 1.0388 - roc_auc: 0.6422 - val_accuracy: 0.4629 - val_loss: 1.0317 - val_roc_auc: 0.6527 - learning_rate: 1.0000e-04
# Epoch 22/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4461 - loss: 1.0338 - roc_auc: 0.6467 - val_accuracy: 0.4706 - val_loss: 1.0246 - val_roc_auc: 0.6642 - learning_rate: 1.0000e-05
# Epoch 23/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4589 - loss: 1.0320 - roc_auc: 0.6480 - val_accuracy: 0.4747 - val_loss: 1.0235 - val_roc_auc: 0.6646 - learning_rate: 1.0000e-05
# Epoch 24/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4529 - loss: 1.0351 - roc_auc: 0.6453 - val_accuracy: 0.4730 - val_loss: 1.0234 - val_roc_auc: 0.6643 - learning_rate: 1.0000e-05
# Epoch 25/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4568 - loss: 1.0313 - roc_auc: 0.6518
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4568 - loss: 1.0313 - roc_auc: 0.6518 - val_accuracy: 0.4730 - val_loss: 1.0230 - val_roc_auc: 0.6648 - learning_rate: 1.0000e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 17.
# Epoch 1/4
# 2024-09-17 21:36:13.122056: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_53', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_58', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_64', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_35', 4 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_34', 4 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_33', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_32', 12 bytes spill stores, 16 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_61', 4 bytes spill stores, 12 bytes spill loads
# 297/298 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.4674 - loss: 1.0309 - roc_auc: 0.6551
# 2024-09-17 21:40:22.243656: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_53', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_58', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_64', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_35', 4 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_34', 4 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_33', 8 bytes spill stores, 8 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_32', 12 bytes spill stores, 16 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_59', 4 bytes spill stores, 12 bytes spill loads
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 379s 885ms/step - accuracy: 0.4674 - loss: 1.0308 - roc_auc: 0.6551 - val_accuracy: 0.4902 - val_loss: 1.0047 - val_roc_auc: 0.6819 - learning_rate: 1.0000e-04
# Epoch 2/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 178s 598ms/step - accuracy: 0.4849 - loss: 1.0003 - roc_auc: 0.6824 - val_accuracy: 0.4985 - val_loss: 1.0000 - val_roc_auc: 0.6876 - learning_rate: 1.0000e-04
# Epoch 3/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 179s 600ms/step - accuracy: 0.5071 - loss: 0.9800 - roc_auc: 0.7007 - val_accuracy: 0.4991 - val_loss: 0.9944 - val_roc_auc: 0.6906 - learning_rate: 1.0000e-04
# Epoch 4/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 151s 505ms/step - accuracy: 0.5114 - loss: 0.9633 - roc_auc: 0.7136 - val_accuracy: 0.5051 - val_loss: 0.9958 - val_roc_auc: 0.6908 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 3.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 16s 200ms/step
# Fold 1...
# Epoch 1/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 98s 271ms/step - accuracy: 0.3507 - loss: 1.1089 - roc_auc: 0.5252 - val_accuracy: 0.4225 - val_loss: 1.0688 - val_roc_auc: 0.6044 - learning_rate: 0.0010
# Epoch 2/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.4132 - loss: 1.0659 - roc_auc: 0.6044 - val_accuracy: 0.4242 - val_loss: 1.0622 - val_roc_auc: 0.6143 - learning_rate: 0.0010
# Epoch 3/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 129ms/step - accuracy: 0.4276 - loss: 1.0555 - roc_auc: 0.6200 - val_accuracy: 0.4391 - val_loss: 1.0486 - val_roc_auc: 0.6323 - learning_rate: 0.0010
# Epoch 4/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 42s 142ms/step - accuracy: 0.4317 - loss: 1.0510 - roc_auc: 0.6239 - val_accuracy: 0.4629 - val_loss: 1.0483 - val_roc_auc: 0.6446 - learning_rate: 0.0010
# Epoch 5/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4411 - loss: 1.0449 - roc_auc: 0.6339 - val_accuracy: 0.4474 - val_loss: 1.0410 - val_roc_auc: 0.6426 - learning_rate: 0.0010
# Epoch 6/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4381 - loss: 1.0490 - roc_auc: 0.6281 - val_accuracy: 0.4124 - val_loss: 1.0582 - val_roc_auc: 0.6128 - learning_rate: 0.0010
# Epoch 7/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4453 - loss: 1.0413 - roc_auc: 0.6385 - val_accuracy: 0.4468 - val_loss: 1.0395 - val_roc_auc: 0.6422 - learning_rate: 0.0010
# Epoch 8/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4444 - loss: 1.0492 - roc_auc: 0.6324 - val_accuracy: 0.4545 - val_loss: 1.0429 - val_roc_auc: 0.6399 - learning_rate: 0.0010
# Epoch 9/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4355 - loss: 1.0430 - roc_auc: 0.6362 - val_accuracy: 0.4480 - val_loss: 1.0370 - val_roc_auc: 0.6450 - learning_rate: 0.0010
# Epoch 10/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4347 - loss: 1.0470 - roc_auc: 0.6307 - val_accuracy: 0.4397 - val_loss: 1.0478 - val_roc_auc: 0.6305 - learning_rate: 0.0010
# Epoch 11/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4536 - loss: 1.0427 - roc_auc: 0.6394 - val_accuracy: 0.4635 - val_loss: 1.0321 - val_roc_auc: 0.6533 - learning_rate: 0.0010
# Epoch 12/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4522 - loss: 1.0409 - roc_auc: 0.6414 - val_accuracy: 0.4641 - val_loss: 1.0450 - val_roc_auc: 0.6445 - learning_rate: 0.0010
# Epoch 13/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4523 - loss: 1.0413 - roc_auc: 0.6416 - val_accuracy: 0.4581 - val_loss: 1.0352 - val_roc_auc: 0.6454 - learning_rate: 0.0010
# Epoch 14/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4426 - loss: 1.0398 - roc_auc: 0.6391 - val_accuracy: 0.4528 - val_loss: 1.0388 - val_roc_auc: 0.6488 - learning_rate: 0.0010
# Epoch 15/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4360 - loss: 1.0433 - roc_auc: 0.6372
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4360 - loss: 1.0433 - roc_auc: 0.6372 - val_accuracy: 0.4528 - val_loss: 1.0391 - val_roc_auc: 0.6442 - learning_rate: 0.0010
# Epoch 16/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4540 - loss: 1.0337 - roc_auc: 0.6481 - val_accuracy: 0.4635 - val_loss: 1.0293 - val_roc_auc: 0.6554 - learning_rate: 1.0000e-04
# Epoch 17/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4473 - loss: 1.0348 - roc_auc: 0.6463 - val_accuracy: 0.4664 - val_loss: 1.0268 - val_roc_auc: 0.6568 - learning_rate: 1.0000e-04
# Epoch 18/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4597 - loss: 1.0324 - roc_auc: 0.6496 - val_accuracy: 0.4700 - val_loss: 1.0274 - val_roc_auc: 0.6576 - learning_rate: 1.0000e-04
# Epoch 19/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4568 - loss: 1.0312 - roc_auc: 0.6515 - val_accuracy: 0.4694 - val_loss: 1.0276 - val_roc_auc: 0.6564 - learning_rate: 1.0000e-04
# Epoch 20/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4533 - loss: 1.0349 - roc_auc: 0.6471 - val_accuracy: 0.4753 - val_loss: 1.0275 - val_roc_auc: 0.6550 - learning_rate: 1.0000e-04
# Epoch 21/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4573 - loss: 1.0328 - roc_auc: 0.6497
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4573 - loss: 1.0328 - roc_auc: 0.6497 - val_accuracy: 0.4712 - val_loss: 1.0270 - val_roc_auc: 0.6583 - learning_rate: 1.0000e-04
# Epoch 22/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4448 - loss: 1.0340 - roc_auc: 0.6469 - val_accuracy: 0.4664 - val_loss: 1.0270 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-05
# Epoch 23/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4620 - loss: 1.0310 - roc_auc: 0.6536 - val_accuracy: 0.4664 - val_loss: 1.0267 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-05
# Epoch 24/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.4503 - loss: 1.0359 - roc_auc: 0.6463 - val_accuracy: 0.4623 - val_loss: 1.0268 - val_roc_auc: 0.6579 - learning_rate: 1.0000e-05
# Epoch 25/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4566 - loss: 1.0270 - roc_auc: 0.6554 - val_accuracy: 0.4623 - val_loss: 1.0268 - val_roc_auc: 0.6578 - learning_rate: 1.0000e-05
# Epoch 26/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4608 - loss: 1.0307 - roc_auc: 0.6512 - val_accuracy: 0.4664 - val_loss: 1.0266 - val_roc_auc: 0.6583 - learning_rate: 1.0000e-05
# Epoch 27/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4542 - loss: 1.0346 - roc_auc: 0.6481 - val_accuracy: 0.4652 - val_loss: 1.0266 - val_roc_auc: 0.6582 - learning_rate: 1.0000e-05
# Epoch 28/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.4593 - loss: 1.0237 - roc_auc: 0.6590 - val_accuracy: 0.4658 - val_loss: 1.0264 - val_roc_auc: 0.6582 - learning_rate: 1.0000e-05
# Epoch 29/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4560 - loss: 1.0311 - roc_auc: 0.6492 - val_accuracy: 0.4676 - val_loss: 1.0264 - val_roc_auc: 0.6579 - learning_rate: 1.0000e-05
# Epoch 30/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4510 - loss: 1.0321 - roc_auc: 0.6500 - val_accuracy: 0.4646 - val_loss: 1.0265 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-05
# Epoch 31/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4597 - loss: 1.0306 - roc_auc: 0.6514 - val_accuracy: 0.4641 - val_loss: 1.0265 - val_roc_auc: 0.6582 - learning_rate: 1.0000e-05
# Epoch 32/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.4545 - loss: 1.0339 - roc_auc: 0.6487
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 155ms/step - accuracy: 0.4544 - loss: 1.0339 - roc_auc: 0.6486 - val_accuracy: 0.4664 - val_loss: 1.0264 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-05
# Epoch 33/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4528 - loss: 1.0345 - roc_auc: 0.6462 - val_accuracy: 0.4676 - val_loss: 1.0264 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-06
# Epoch 34/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4527 - loss: 1.0331 - roc_auc: 0.6474 - val_accuracy: 0.4670 - val_loss: 1.0264 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-06
# Epoch 35/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.4595 - loss: 1.0278 - roc_auc: 0.6545 - val_accuracy: 0.4664 - val_loss: 1.0264 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-06
# Epoch 36/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.4638 - loss: 1.0271 - roc_auc: 0.6561
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 46s 155ms/step - accuracy: 0.4638 - loss: 1.0271 - roc_auc: 0.6561 - val_accuracy: 0.4670 - val_loss: 1.0264 - val_roc_auc: 0.6580 - learning_rate: 1.0000e-06
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Epoch 1/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 296s 751ms/step - accuracy: 0.4558 - loss: 1.0379 - roc_auc: 0.6511 - val_accuracy: 0.4854 - val_loss: 1.0055 - val_roc_auc: 0.6779 - learning_rate: 1.0000e-04
# Epoch 2/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 178s 598ms/step - accuracy: 0.4902 - loss: 0.9975 - roc_auc: 0.6854 - val_accuracy: 0.4967 - val_loss: 0.9972 - val_roc_auc: 0.6858 - learning_rate: 1.0000e-04
# Epoch 3/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 179s 601ms/step - accuracy: 0.5118 - loss: 0.9746 - roc_auc: 0.7057 - val_accuracy: 0.5027 - val_loss: 0.9941 - val_roc_auc: 0.6893 - learning_rate: 1.0000e-04
# Epoch 4/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 178s 598ms/step - accuracy: 0.5131 - loss: 0.9661 - roc_auc: 0.7117 - val_accuracy: 0.4926 - val_loss: 0.9928 - val_roc_auc: 0.6903 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 4.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step
# Fold 2...
# Epoch 1/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 198s 597ms/step - accuracy: 0.3634 - loss: 1.1095 - roc_auc: 0.5371 - val_accuracy: 0.4450 - val_loss: 1.0666 - val_roc_auc: 0.6165 - learning_rate: 0.0010
# Epoch 2/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4032 - loss: 1.0773 - roc_auc: 0.5870 - val_accuracy: 0.4617 - val_loss: 1.0358 - val_roc_auc: 0.6608 - learning_rate: 0.0010
# Epoch 3/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4243 - loss: 1.0599 - roc_auc: 0.6134 - val_accuracy: 0.4468 - val_loss: 1.0474 - val_roc_auc: 0.6402 - learning_rate: 0.0010
# Epoch 4/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 160ms/step - accuracy: 0.4260 - loss: 1.0563 - roc_auc: 0.6195 - val_accuracy: 0.4783 - val_loss: 1.0249 - val_roc_auc: 0.6664 - learning_rate: 0.0010
# Epoch 5/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 160ms/step - accuracy: 0.4348 - loss: 1.0521 - roc_auc: 0.6274 - val_accuracy: 0.4664 - val_loss: 1.0200 - val_roc_auc: 0.6716 - learning_rate: 0.0010
# Epoch 6/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 160ms/step - accuracy: 0.4416 - loss: 1.0493 - roc_auc: 0.6304 - val_accuracy: 0.4771 - val_loss: 1.0180 - val_roc_auc: 0.6713 - learning_rate: 0.0010
# Epoch 7/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4328 - loss: 1.0524 - roc_auc: 0.6273 - val_accuracy: 0.4831 - val_loss: 1.0185 - val_roc_auc: 0.6774 - learning_rate: 0.0010
# Epoch 8/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4490 - loss: 1.0505 - roc_auc: 0.6321 - val_accuracy: 0.4759 - val_loss: 1.0221 - val_roc_auc: 0.6717 - learning_rate: 0.0010
# Epoch 9/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4394 - loss: 1.0518 - roc_auc: 0.6279 - val_accuracy: 0.4225 - val_loss: 1.0462 - val_roc_auc: 0.6306 - learning_rate: 0.0010
# Epoch 10/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4360 - loss: 1.0541 - roc_auc: 0.6259
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4360 - loss: 1.0541 - roc_auc: 0.6259 - val_accuracy: 0.4593 - val_loss: 1.0231 - val_roc_auc: 0.6590 - learning_rate: 0.0010
# Epoch 11/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4535 - loss: 1.0457 - roc_auc: 0.6364 - val_accuracy: 0.4884 - val_loss: 1.0122 - val_roc_auc: 0.6835 - learning_rate: 1.0000e-04
# Epoch 12/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4558 - loss: 1.0424 - roc_auc: 0.6417 - val_accuracy: 0.4902 - val_loss: 1.0088 - val_roc_auc: 0.6843 - learning_rate: 1.0000e-04
# Epoch 13/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4399 - loss: 1.0479 - roc_auc: 0.6326 - val_accuracy: 0.4896 - val_loss: 1.0099 - val_roc_auc: 0.6836 - learning_rate: 1.0000e-04
# Epoch 14/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 160ms/step - accuracy: 0.4521 - loss: 1.0358 - roc_auc: 0.6476 - val_accuracy: 0.4926 - val_loss: 1.0083 - val_roc_auc: 0.6846 - learning_rate: 1.0000e-04
# Epoch 15/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4491 - loss: 1.0386 - roc_auc: 0.6435 - val_accuracy: 0.4926 - val_loss: 1.0116 - val_roc_auc: 0.6841 - learning_rate: 1.0000e-04
# Epoch 16/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4470 - loss: 1.0367 - roc_auc: 0.6452 - val_accuracy: 0.4914 - val_loss: 1.0092 - val_roc_auc: 0.6843 - learning_rate: 1.0000e-04
# Epoch 17/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4501 - loss: 1.0373 - roc_auc: 0.6457 - val_accuracy: 0.4896 - val_loss: 1.0108 - val_roc_auc: 0.6842 - learning_rate: 1.0000e-04
# Epoch 18/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4476 - loss: 1.0446 - roc_auc: 0.6377
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4476 - loss: 1.0446 - roc_auc: 0.6377 - val_accuracy: 0.4854 - val_loss: 1.0119 - val_roc_auc: 0.6829 - learning_rate: 1.0000e-04
# Epoch 19/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4419 - loss: 1.0447 - roc_auc: 0.6354 - val_accuracy: 0.4914 - val_loss: 1.0098 - val_roc_auc: 0.6857 - learning_rate: 1.0000e-05
# Epoch 20/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4592 - loss: 1.0392 - roc_auc: 0.6462 - val_accuracy: 0.4932 - val_loss: 1.0090 - val_roc_auc: 0.6860 - learning_rate: 1.0000e-05
# Epoch 21/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4476 - loss: 1.0375 - roc_auc: 0.6435 - val_accuracy: 0.4902 - val_loss: 1.0085 - val_roc_auc: 0.6858 - learning_rate: 1.0000e-05
# Epoch 22/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4409 - loss: 1.0491 - roc_auc: 0.6313
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4409 - loss: 1.0490 - roc_auc: 0.6313 - val_accuracy: 0.4908 - val_loss: 1.0092 - val_roc_auc: 0.6855 - learning_rate: 1.0000e-05
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Epoch 1/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 296s 752ms/step - accuracy: 0.4509 - loss: 1.0482 - roc_auc: 0.6463 - val_accuracy: 0.4985 - val_loss: 0.9875 - val_roc_auc: 0.6991 - learning_rate: 1.0000e-04
# Epoch 2/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 179s 599ms/step - accuracy: 0.4965 - loss: 1.0013 - roc_auc: 0.6853 - val_accuracy: 0.5009 - val_loss: 0.9761 - val_roc_auc: 0.7065 - learning_rate: 1.0000e-04
# Epoch 3/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 179s 602ms/step - accuracy: 0.5044 - loss: 0.9899 - roc_auc: 0.6959 - val_accuracy: 0.5146 - val_loss: 0.9731 - val_roc_auc: 0.7088 - learning_rate: 1.0000e-04
# Epoch 4/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 179s 599ms/step - accuracy: 0.5085 - loss: 0.9797 - roc_auc: 0.7021 - val_accuracy: 0.5062 - val_loss: 0.9711 - val_roc_auc: 0.7120 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 4.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 15s 207ms/step
# Fold 3...
# Epoch 1/40
# 2024-09-17 23:06:22.837757: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:42: Filling up shuffle buffer (this may take a while): 485 of 1000
# 2024-09-17 23:06:32.949439: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:42: Filling up shuffle buffer (this may take a while): 848 of 1000
# 2024-09-17 23:06:35.737072: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 307s 913ms/step - accuracy: 0.3451 - loss: 1.1120 - roc_auc: 0.5190 - val_accuracy: 0.4201 - val_loss: 1.0657 - val_roc_auc: 0.6090 - learning_rate: 0.0010
# Epoch 2/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.3996 - loss: 1.0751 - roc_auc: 0.5909 - val_accuracy: 0.4023 - val_loss: 1.0531 - val_roc_auc: 0.6219 - learning_rate: 0.0010
# Epoch 3/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4147 - loss: 1.0646 - roc_auc: 0.6056 - val_accuracy: 0.4510 - val_loss: 1.0348 - val_roc_auc: 0.6568 - learning_rate: 0.0010
# Epoch 4/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4329 - loss: 1.0550 - roc_auc: 0.6250 - val_accuracy: 0.4902 - val_loss: 1.0221 - val_roc_auc: 0.6711 - learning_rate: 0.0010
# Epoch 5/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4374 - loss: 1.0526 - roc_auc: 0.6255 - val_accuracy: 0.4771 - val_loss: 1.0214 - val_roc_auc: 0.6715 - learning_rate: 0.0010
# Epoch 6/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 160ms/step - accuracy: 0.4329 - loss: 1.0586 - roc_auc: 0.6176 - val_accuracy: 0.4908 - val_loss: 1.0152 - val_roc_auc: 0.6729 - learning_rate: 0.0010
# Epoch 7/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 48s 160ms/step - accuracy: 0.4369 - loss: 1.0547 - roc_auc: 0.6248 - val_accuracy: 0.4510 - val_loss: 1.0324 - val_roc_auc: 0.6504 - learning_rate: 0.0010
# Epoch 8/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4260 - loss: 1.0515 - roc_auc: 0.6264 - val_accuracy: 0.4890 - val_loss: 1.0282 - val_roc_auc: 0.6771 - learning_rate: 0.0010
# Epoch 9/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4373 - loss: 1.0462 - roc_auc: 0.6336 - val_accuracy: 0.4314 - val_loss: 1.0378 - val_roc_auc: 0.6418 - learning_rate: 0.0010
# Epoch 10/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4337 - loss: 1.0552 - roc_auc: 0.6213
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4337 - loss: 1.0552 - roc_auc: 0.6213 - val_accuracy: 0.4920 - val_loss: 1.0170 - val_roc_auc: 0.6800 - learning_rate: 0.0010
# Epoch 11/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4387 - loss: 1.0432 - roc_auc: 0.6359 - val_accuracy: 0.4789 - val_loss: 1.0152 - val_roc_auc: 0.6788 - learning_rate: 1.0000e-04
# Epoch 12/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4414 - loss: 1.0443 - roc_auc: 0.6337 - val_accuracy: 0.4878 - val_loss: 1.0115 - val_roc_auc: 0.6800 - learning_rate: 1.0000e-04
# Epoch 13/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4526 - loss: 1.0375 - roc_auc: 0.6433 - val_accuracy: 0.4926 - val_loss: 1.0117 - val_roc_auc: 0.6785 - learning_rate: 1.0000e-04
# Epoch 14/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4515 - loss: 1.0375 - roc_auc: 0.6438 - val_accuracy: 0.4896 - val_loss: 1.0113 - val_roc_auc: 0.6805 - learning_rate: 1.0000e-04
# Epoch 15/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.4505 - loss: 1.0379 - roc_auc: 0.6442 - val_accuracy: 0.4890 - val_loss: 1.0102 - val_roc_auc: 0.6805 - learning_rate: 1.0000e-04
# Epoch 16/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4476 - loss: 1.0395 - roc_auc: 0.6416 - val_accuracy: 0.4854 - val_loss: 1.0129 - val_roc_auc: 0.6792 - learning_rate: 1.0000e-04
# Epoch 17/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4435 - loss: 1.0422 - roc_auc: 0.6389 - val_accuracy: 0.4771 - val_loss: 1.0106 - val_roc_auc: 0.6814 - learning_rate: 1.0000e-04
# Epoch 18/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.4541 - loss: 1.0373 - roc_auc: 0.6440 - val_accuracy: 0.4884 - val_loss: 1.0113 - val_roc_auc: 0.6804 - learning_rate: 1.0000e-04
# Epoch 19/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4522 - loss: 1.0362 - roc_auc: 0.6469
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 41s 139ms/step - accuracy: 0.4522 - loss: 1.0362 - roc_auc: 0.6469 - val_accuracy: 0.4866 - val_loss: 1.0102 - val_roc_auc: 0.6809 - learning_rate: 1.0000e-04
# Epoch 20/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.4547 - loss: 1.0343 - roc_auc: 0.6473 - val_accuracy: 0.4807 - val_loss: 1.0094 - val_roc_auc: 0.6824 - learning_rate: 1.0000e-05
# Epoch 21/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.4547 - loss: 1.0388 - roc_auc: 0.6439 - val_accuracy: 0.4765 - val_loss: 1.0100 - val_roc_auc: 0.6821 - learning_rate: 1.0000e-05
# Epoch 22/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 129ms/step - accuracy: 0.4495 - loss: 1.0376 - roc_auc: 0.6448 - val_accuracy: 0.4777 - val_loss: 1.0098 - val_roc_auc: 0.6823 - learning_rate: 1.0000e-05
# Epoch 23/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.4525 - loss: 1.0389 - roc_auc: 0.6433 - val_accuracy: 0.4765 - val_loss: 1.0098 - val_roc_auc: 0.6822 - learning_rate: 1.0000e-05
# Epoch 24/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4457 - loss: 1.0443 - roc_auc: 0.6361
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.4458 - loss: 1.0443 - roc_auc: 0.6361 - val_accuracy: 0.4789 - val_loss: 1.0099 - val_roc_auc: 0.6823 - learning_rate: 1.0000e-05
# Epoch 25/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 39s 129ms/step - accuracy: 0.4487 - loss: 1.0376 - roc_auc: 0.6429 - val_accuracy: 0.4777 - val_loss: 1.0099 - val_roc_auc: 0.6822 - learning_rate: 1.0000e-06
# Epoch 26/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 129ms/step - accuracy: 0.4560 - loss: 1.0365 - roc_auc: 0.6473 - val_accuracy: 0.4771 - val_loss: 1.0099 - val_roc_auc: 0.6822 - learning_rate: 1.0000e-06
# Epoch 27/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 129ms/step - accuracy: 0.4526 - loss: 1.0331 - roc_auc: 0.6490 - val_accuracy: 0.4777 - val_loss: 1.0099 - val_roc_auc: 0.6821 - learning_rate: 1.0000e-06
# Epoch 28/40
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4428 - loss: 1.0396 - roc_auc: 0.6413
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 38s 128ms/step - accuracy: 0.4428 - loss: 1.0395 - roc_auc: 0.6413 - val_accuracy: 0.4777 - val_loss: 1.0099 - val_roc_auc: 0.6821 - learning_rate: 1.0000e-06
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 20.
# Epoch 1/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 259s 622ms/step - accuracy: 0.4580 - loss: 1.0459 - roc_auc: 0.6494 - val_accuracy: 0.5003 - val_loss: 0.9899 - val_roc_auc: 0.6968 - learning_rate: 1.0000e-04
# Epoch 2/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 139s 467ms/step - accuracy: 0.4830 - loss: 1.0059 - roc_auc: 0.6809 - val_accuracy: 0.5045 - val_loss: 0.9861 - val_roc_auc: 0.6973 - learning_rate: 1.0000e-04
# Epoch 3/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 141s 472ms/step - accuracy: 0.4965 - loss: 0.9873 - roc_auc: 0.6961 - val_accuracy: 0.5140 - val_loss: 0.9755 - val_roc_auc: 0.7062 - learning_rate: 1.0000e-04
# Epoch 4/4
# 298/298 ━━━━━━━━━━━━━━━━━━━━ 141s 472ms/step - accuracy: 0.5053 - loss: 0.9732 - roc_auc: 0.7071 - val_accuracy: 0.5092 - val_loss: 0.9713 - val_roc_auc: 0.7089 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 4.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step

# %%
from IPython.display import display

results_csv_exists = os.path.isfile('resultados_folds.csv')
tprs_csv_exists = os.path.isfile('tprs_folds.csv')

results_df = pandas.DataFrame({
    'auc': aucs,
})

results_df.to_csv(
    path_or_buf='resultados_folds.csv',
    mode='a' if results_csv_exists else 'w',
    header=not results_csv_exists,
    index=False
)

tprs_df = pandas.DataFrame(tprs)
tprs_df.to_csv(
    path_or_buf='tprs_folds.csv',
    mode='a' if tprs_csv_exists else 'w',
    header=not tprs_csv_exists,
    index=False
)

# # Gerando curva roc
# mean_tpr = numpy.mean(tprs, axis=0)
# mean_tpr[-1] = 1.0
# mean_auc = auc(mean_fpr, mean_tpr)
# std_auc = numpy.std(aucs)
# ax.plot(
#     mean_fpr,
#     mean_tpr,
#     color="b",
#     label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
#     lw=2,
#     alpha=0.8,
# )
# std_tpr = numpy.std(tprs, axis=0)
# tprs_upper = numpy.minimum(mean_tpr + std_tpr, 1)
# tprs_lower = numpy.maximum(mean_tpr - std_tpr, 0)
# ax.fill_between(
#     mean_fpr,
#     tprs_lower,
#     tprs_upper,
#     color="grey",
#     alpha=0.2,
#     label=r"$\pm$ 1 std. dev.",
# )
# ax.set(
#     xlabel="False Positive Rate",
#     ylabel="True Positive Rate",
#     title=f"Mean ROC curve with variability\n(Positive label '{uncertain}')",
# )
# ax.legend(loc="lower right")
# plt.show()

# %%
# from scipy.stats import ttest_1samp

# t_stat, p_value = ttest_1samp(aucs, 0.5, alternative='greater')
# alpha = 0.05

# print("T statistic:", t_stat)
# print("P-value:", p_value)

# if p_value < alpha:
#     print('Null hypothesis rejected')

# else:
#     print('Failed to reject null hypothesis')
